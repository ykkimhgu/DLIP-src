# %% [markdown]
# <a href="https://colab.research.google.com/github/ykkimhgu/DLIP-src/blob/main/Assignment_Keras_MLP_FashionMNIST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Assignment :   MLP using Keras**
# ## Fashion MNIST Classification
# Y.-K. Kim
# (updated 2021. 5. 12)
#
# ## Reference
#
# https://www.tensorflow.org/tutorials/keras/classification?hl=ko
#
#  https://keras.io/guides/sequential_model/

# %% [markdown]
# ## Your Name: _____________

# %% [markdown]
# ---
# ## Import Keras and Numpy

# %%
import tensorflow as tf
print(tf.__version__)

from tensorflow import keras
from tensorflow.keras import layers
print(keras.__version__)

from keras.models import Sequential
from keras.layers.core import Dense, Activation
from keras.optimizers import SGD
import numpy as np 

import matplotlib.pyplot as plt
from matplotlib import pyplot

# %% [markdown]
# ## Import Dataset: Fashion MNIST

# %% [markdown]
# https://keras.io/api/datasets/fashion_mnist/
#
# This is a dataset of 60,000 28x28 grayscale images of 10 fashion categories, along with a test set of 10,000 images. This dataset can be used as a drop-in replacement for MNIST.
#
# <table>
#   <tr><td>
#     <img src="https://tensorflow.org/images/fashion-mnist-sprite.png"
#          alt="Fashion MNIST sprite"  width="600">
#   </td></tr>
#   <tr><td align="center">
#     <b>그림 1.</b> <a href="https://github.com/zalandoresearch/fashion-mnist">Fashion-MNIST Sample</a> (Zalando, MIT License).<br/>&nbsp;
#   </td></tr>
# </table>
#
# Label	Description
#
# <table>
#   <tr>
#     <th>Label</th>
#     <th>Class</th>
#   </tr>
#   <tr>
#     <td>0</td>
#     <td>T-shirt/top</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Trouser</td>
#   </tr>
#     <tr>
#     <td>2</td>
#     <td>Pullover</td>
#   </tr>
#     <tr>
#     <td>3</td>
#     <td>Dress</td>
#   </tr>
#     <tr>
#     <td>4</td>
#     <td>Coat</td>
#   </tr>
#     <tr>
#     <td>5</td>
#     <td>Sandal</td>
#   </tr>
#     <tr>
#     <td>6</td>
#     <td>Shirt</td>
#   </tr>
#     <tr>
#     <td>7</td>
#     <td>Sneaker</td>
#   </tr>
#     <tr>
#     <td>8</td>
#     <td>Bag</td>
#   </tr>
#     <tr>
#     <td>9</td>
#     <td>Ankle boot</td>
#   </tr>
# </table>

# %%
fashion_mnist = keras.datasets.fashion_mnist

(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

train_labels0=train_labels
test_labels0=test_labels

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ## Data Anlaysis

# %%
print(train_images.shape)
print(len(train_labels))
train_labels

# %% [markdown]
# ### Open and Plot some of the image datasets

# %%
# plot first image in color
pyplot.figure()
pyplot.imshow(train_images[0])
pyplot.colorbar()
pyplot.grid(False)
pyplot.show()

# plot first 25 images
pyplot.figure(figsize=(10,10))
for i in range(25):
  # define subplot
  pyplot.subplot(5,5,i+1)
  plt.xticks([])
  plt.yticks([])  
  pyplot.imshow(train_images[i], cmap=pyplot.get_cmap('gray'))
  pyplot.xlabel(class_names[train_labels[i]])
# show the figure
pyplot.show()

# %% [markdown]
# ### Normalization of dataset
# Scale images to [0,1] range for normalization in 8-bit

# %%
# Scale images to [0,1] range for normalization and 8-bit grayscale
#  **numpy.ndarray.astype** changes data type
train_images=train_images.astype("float32")/255
test_images=test_images.astype("float32")/255

# Check the dimension of data
print("check data dim")
print("train shape:", train_images)
print("test shape:", test_images)

# make sure images have shape (28, 28, 1)
# careful not to execute repeatevily. For it augments new axis

# %% [markdown]
# Convert label vectors to binary class matrices ' Categorical'

# %% [markdown]
# ### Flatten the input data
# Reshape the data  to 1-D input data form for MLP.
#
# Look for  .reshape() method

# %%
# Flatthen the image (28x28) into  1-D input data form for MLP.
# ADD YOUR CODE HERE

# %% [markdown]
#  Convert class vectors to binary class matrices ' Categorical'  "One-Hot Encoding"

# %%
train_labels=keras.utils.to_categorical(train_labels, num_classes)
test_tabels =keras.utils.to_categorical(test_labels, num_classes)
display(train_labels.shape)
display(train_labels[0])

# %% [markdown]
# ## Build MLP Model

# %% [markdown]
# **Build your own MLP model**
# You can choose
# 1. number of layers and nodes
# 2. Activation functions  ('relu etc')
# 3. Optimization types
# 4. Batch size
#
# BUT, for the output layer, use
#   `keras.layers.Dense(10, activation='softmax')`

# %%
num_classes = 10

model = keras.Sequential([    
    # ADD YOUR LAYERE HERE
    # ADD YOUR LAYERE HERE
    # ADD YOUR LAYERE HERE    
    keras.layers.Dense(10, activation='softmax')
])

# %%
model.summary()

# %% [markdown]
# `model.compile(   )`
#
#
# Use
# *               loss='categorical_crossentropy',
# *               metrics=['accuracy'])

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# ## Train the model
# Model.fit() method

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# ## Evaluate the trained model

# %%
score=model.evaluate(test_images, test_labels, verbose=1)
print("Test loss:", score[0])
print("Test accuracy: ", score[1])

# %% [markdown]
# ## Analyze the performance
# Check which images were NOT classificed correctly.
# Plot some correct and incorrect examples

# %%
# ADD YOUR CODE HERE
